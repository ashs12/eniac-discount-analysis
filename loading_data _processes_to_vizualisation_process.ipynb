# %%
import os
os.getcwd()
# Out:
# '/Users/ashutoshsaini/eniac-discount-analysis/notebooks'

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

orders_df = pd.read_csv('../data/raw/orders.csv')

# %%
orders_orig = orders_df.copy()

# %%
orderlines_df = pd.read_csv('../data/raw/orderlines.csv')

# %%
products_df = pd.read_csv('../data/raw/products.csv')

# %%
brands_df = pd.read_csv('../data/raw/brands.csv')

# %%
orders_df.head(10)
# Out:
#    order_id         created_date  total_paid      state
# 0    241319  2017-01-02 13:35:40       44.99  Cancelled
# 1    241423  2017-11-06 13:10:02      136.15  Completed
# 2    242832  2017-12-31 17:40:03       15.76  Completed
# 3    243330  2017-02-16 10:59:38       84.98  Completed
# 4    243784  2017-11-24 13:35:19      157.86  Cancelled
# 5    245275  2017-06-28 11:35:37      149.00  Completed
# 6    245595  2017-01-21 12:52:47      112.97  Completed
# 7    245851  2017-04-04 20:58:21       79.99    Pending
# 8    245941  2017-01-01 10:32:23      183.52  Completed
# 9    246018  2017-02-13 23:02:57      211.95  Completed

# %%
orders_df.nunique()
# Out:
# order_id        226909
# created_date    224828
# total_paid       31236
# state                5
# dtype: int64

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %%
orders_df.isnull().any()
# Out:
# order_id        False
# created_date    False
# total_paid       True
# state           False
# dtype: bool

# %%
orders_df.isnull().sum()
# Out:
# order_id        0
# created_date    0
# total_paid      5
# state           0
# dtype: int64

# %%
orders_df['order_id'].unique()
# Out:
# array([241319, 241423, 242832, ..., 527399, 527400, 527401])

# %%
state_mask = orders_df['state'] == 'Completed'
#state_mask
orders_df.loc[state_mask].nunique()
# Out:
# order_id        46605
# created_date    46506
# total_paid      12834
# state               1
# dtype: int64

# %%
#state_mask.isnull().sum 

#this is not helping me, my fault here was that I was using boolean on a Series and not a df.

# %%
completed_orders = orders_df.loc[state_mask]

completed_orders['total_paid'].isnull().sum()
# Out:
# np.int64(0)

# %%
#I would like to know the number of completed orders

state_mask.value_counts()
# Out:
# state
# False    180304
# True      46605
# Name: count, dtype: int64

# %%
# I would now like to know the percentage of completed orders, just to make proportion of completed orders more visible

completed_orders_percentage = (state_mask.sum()/len(state_mask))*100

completed_orders_percentage
# Out:
# np.float64(20.53907072879436)

# %% [markdown]
# Only 20.54% of orders(completed orders) contribute to the total revenue of Eniac

# %%
#I will now calculate the percenatge of pending and cancelled orders

pending_order_mask = orders_df['state'] == 'Pending'

pending_orders_count = (orders_df['state'] == 'Pending').sum()
percentage_of_pending_orders = (pending_orders_count/len(pending_order_mask))*100

percentage_of_pending_orders
# Out:
# np.float64(6.336901577284286)

# %%
cancelled_order_mask = orders_df['state'] == 'Cancelled'

cancelled_orders_count = (orders_df['state'] == 'Cancelled').sum()
percentage_of_cancelled_orders = (cancelled_orders_count/len(cancelled_order_mask))*100

percentage_of_cancelled_orders
# Out:
# np.float64(3.187621469399627)

# %% [markdown]
# # Now I will calculate the percentage share of Shopping Basket orders and Place Order state.

# %%
shopping_basket_order_mask = orders_df['state'] == 'Shopping Basket'

shopping_basket_order_mask_count = (orders_df['state'] == 'Shopping Basket').sum()
percentage_of_shopping_basket_order_mask = (shopping_basket_order_mask_count/len(shopping_basket_order_mask))*100

percentage_of_shopping_basket_order_mask
# Out:
# np.float64(51.9190512496199)

# %%
place_order_mask = orders_df['state'] == 'Place Order'

place_order_mask_count = (orders_df['state'] == 'Place Order').sum()
percentage_of_place_order_mask = (place_order_mask_count/len(place_order_mask))*100

percentage_of_place_order_mask
# Out:
# np.float64(18.017354974901835)

# %%
(orders_df['state'].value_counts(normalize=True) * 100)#.sum()
# Out:
# state
# Shopping Basket    51.919051
# Completed          20.539071
# Place Order        18.017355
# Pending             6.336902
# Cancelled           3.187621
# Name: proportion, dtype: float64

# %%
# sanity Check

total_state_masks_count = percentage_of_pending_orders + percentage_of_shopping_basket_order_mask + percentage_of_cancelled_orders + completed_orders_percentage + percentage_of_place_order_mask


total_state_masks_count
# Out:
# np.float64(100.00000000000001)

# %% [markdown]
# The Shopping Basket orders account for ~51.92% and Completed orders account for ~20.54%.

# %%
completed_orders = orders_df.loc[state_mask]

completed_orders_df = completed_orders.copy()

# %%
orderlines_df.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40
# 4  2017-01-01 01:06:38

# %%
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %% [markdown]
# My next dataframe to explore is orderlines_df

# %%
orderlines_df_original = orderlines_df.copy()

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %%
orderlines_df.head(15)
# Out:
#          id  id_order  product_id  product_quantity      sku unit_price  \
# 0   1119109    299539           0                 1  OTT0133      18.99
# 1   1119110    299540           0                 1  LGE0043     399.00
# 2   1119111    299541           0                 1  PAR0071     474.05
# 3   1119112    299542           0                 1  WDT0315      68.39
# 4   1119113    299543           0                 1  JBL0104      23.74
# 5   1119114    295310           0                10  WDT0249     231.79
# 6   1119115    299544           0                 1  APP1582   1.137.99
# 7   1119116    299545           0                 1  OWC0100      47.49
# 8   1119119    299546           0                 1  IOT0014      18.99
# 9   1119120    295347           0                 1  APP0700      72.19
# 10  1119125    299548           0                 5  SPE0132      35.14
# 11  1119126    299549           0                 1  PAC0929   2.565.99
# 12  1119127    299550           0                 1  WDT0309     149.14
# 13  1119129    299552           0                 1  MBI0010      16.99
# 14  1119130    299552           0                 1  SAT0044      19.99
#
#                    date
# 0   2017-01-01 00:07:19
# 1   2017-01-01 00:19:45
# 2   2017-01-01 00:20:57
# 3   2017-01-01 00:51:40
# 4   2017-01-01 01:06:38
# 5   2017-01-01 01:14:27
# 6   2017-01-01 01:17:21
# 7   2017-01-01 01:46:16
# 8   2017-01-01 01:50:34
# 9   2017-01-01 01:54:11
# 10  2017-01-01 02:02:20
# 11  2017-01-01 02:07:42
# 12  2017-01-01 02:09:52
# 13  2017-01-01 02:13:51
# 14  2017-01-01 02:14:36

# %%
orderlines_df.isnull().sum()
# Out:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64

# %%
orderlines_df.nunique()
# Out:
# id                  293983
# id_order            204855
# product_id               1
# product_quantity        67
# sku                   7951
# unit_price           11329
# date                251631
# dtype: int64

# %%
orderlines_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# I will now change the Datatypes for date column to Datetime and unit_price to int

# %%
orderlines_df['date'] = pd.to_datetime(orderlines_df['date'], errors = 'coerce')

# %%
orderlines_df['unit_price'] = pd.to_numeric(orderlines_df['unit_price'], errors = 'coerce')

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        257814 non-null  float64
#  6   date              293983 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 15.7+ MB

# %%
orderlines_df.isnull().sum()
# Out:
# id                      0
# id_order                0
# product_id              0
# product_quantity        0
# sku                     0
# unit_price          36169
# date                    0
# dtype: int64

# %%
orderlines_df.loc[:,['unit_price','sku']].isnull().value_counts()
# Out:
# unit_price  sku
# False       False    257814
# True        False     36169
# Name: count, dtype: int64

# %% [markdown]
# Finally after exploring the orderlines_df I will move to products_df

# %%
products_df_orig = products_df.copy()

# %%
products_df.head(20)
# Out:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
#
#                                                  desc  price promo_price  \
# 0        Aluminum support compatible with all MacBook  59.99     499.899
# 1           USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                              mouse Apple USB cable.     59     569.898
# 3               IPhone dock and USB Cable Apple iPod.     25     229.997
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# 5   IPhone and iPod AV Cable Dock to Composite Video.     45     420.003
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99     146.471
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99     274.694
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...     74     669.904
# 9   Adapter Mini Display Port to VGA MacBook and M...     35     330.003
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...     35     330.003
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.  49.99     449.878
# 12                       USB to Ethernet adapter Mac.     35     330.003
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).     89     849.904
# 14           FireWire 400 adapter cable FireWire 800.     20     179.891
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...  24.95     249.889
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...     89     849.904
# 17  Dock and support with multiple connections for...  69.99     699.864
# 18                  Case iPhone 4 / 4S polycarbonate.   9.99       7.986
# 19                         Dock Connector to VGA IOS.     35     350.005
#
#     in_stock      type
# 0          1      8696
# 1          0  13855401
# 2          0      1387
# 3          0      1230
# 4          1      1364
# 5          0      1230
# 6          0      1364
# 7          0      1364
# 8          0      1364
# 9          0      1325
# 10         0      1325
# 11         0      5384
# 12         0      1334
# 13         0  13005399
# 14         0      1325
# 15         0  13835403
# 16         1  13005399
# 17         0  12995397
# 18         0  11865403
# 19         0  13955395

# %%
products_df.isnull().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          46
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
products_df.duplicated().value_counts()
# Out:
# False    10580
# True      8746
# Name: count, dtype: int64

# %%
duplicated_rows_mask = products_df['sku'].duplicated()

products_df.loc[duplicated_rows_mask]
# Out:
#            sku                                               name  \
# 101    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 102    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 103    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 104    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 105    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# ...        ...                                                ...
# 16831  APP2302  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 16833  APP2303  Apple MacBook Pro 13 "Core i5 Touch Bar 33GHz ...
# 18190  PAR0077                         Parrot Bebop Drone 2 Power
# 18308  NKI0010              Nokia Wireless sphygmomanometer Plata
# 18514  PLA0035          Bluetooth Headset Plantronics Explorer 80
#
#                                                     desc        price  \
# 101          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 102          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 103          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 104          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# 105          MacBook Pro laptop 133 inches (MD101Y / A).         1199
# ...                                                  ...          ...
# 16831  New MacBook Pro 13-inch Core i5 Touch Bar 33 G...   26.155.941
# 16833  New MacBook Pro 13 inch Touch Bar 33 GHz Core ...  237.559.421
# 18190  Drone cuadricóptero quality camera integrated ...        699.9
# 18308     Sphygmomanometer for iPhone iPad and iPod App.       129.99
# 18514  egonómico wireless headset design for iPhone i...        39.99
#
#       promo_price  in_stock      type
# 101    11.455.917         0      1282
# 102    11.455.917         0      1282
# 103    11.455.917         0      1282
# 104    11.455.917         0      1282
# 105    11.455.917         0      1282
# ...           ...       ...       ...
# 16831  26.155.941         0  1,02E+12
# 16833  23.755.942         0  1,02E+12
# 18190   6.733.892         0  11905404
# 18308   1.149.899         1  11905404
# 18514     349.896         1      5384
#
# [8747 rows x 7 columns]

# %%
duplicated_sku_mask = products_df['sku'] == 'APP0390'

# %%
duplicate_sku = products_df.loc[duplicated_sku_mask]

duplicate_sku.duplicated().sum()
# Out:
# np.int64(8)

# %%
duplicate_sku.nunique()
# Out:
# sku            1
# name           1
# desc           1
# price          1
# promo_price    1
# in_stock       1
# type           1
# dtype: int64

# %%
duplicated_skus = products_df[products_df['sku'].duplicated(keep=False)]
duplicated_skus
# Out:
#            sku                                               name  \
# 100    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 101    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 102    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 103    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# 104    APP0390  Apple MacBook Pro 133 "Core i5 25GHz | 4GB RAM...
# ...        ...                                                ...
# 18190  PAR0077                         Parrot Bebop Drone 2 Power
# 18307  NKI0010              Nokia Wireless sphygmomanometer Plata
# 18308  NKI0010              Nokia Wireless sphygmomanometer Plata
# 18513  PLA0035          Bluetooth Headset Plantronics Explorer 80
# 18514  PLA0035          Bluetooth Headset Plantronics Explorer 80
#
#                                                     desc   price promo_price  \
# 100          MacBook Pro laptop 133 inches (MD101Y / A).    1199  11.455.917
# 101          MacBook Pro laptop 133 inches (MD101Y / A).    1199  11.455.917
# 102          MacBook Pro laptop 133 inches (MD101Y / A).    1199  11.455.917
# 103          MacBook Pro laptop 133 inches (MD101Y / A).    1199  11.455.917
# 104          MacBook Pro laptop 133 inches (MD101Y / A).    1199  11.455.917
# ...                                                  ...     ...         ...
# 18190  Drone cuadricóptero quality camera integrated ...   699.9   6.733.892
# 18307     Sphygmomanometer for iPhone iPad and iPod App.  129.99   1.149.899
# 18308     Sphygmomanometer for iPhone iPad and iPod App.  129.99   1.149.899
# 18513  egonómico wireless headset design for iPhone i...   39.99     349.896
# 18514  egonómico wireless headset design for iPhone i...   39.99     349.896
#
#        in_stock      type
# 100           0      1282
# 101           0      1282
# 102           0      1282
# 103           0      1282
# 104           0      1282
# ...         ...       ...
# 18190         0  11905404
# 18307         1  11905404
# 18308         1  11905404
# 18513         1      5384
# 18514         1      5384
#
# [9504 rows x 7 columns]

# %% [markdown]
# Important part starts now, this includes the removal of the hazardous skus from the dataframe

# %%
duplicated_skus.groupby('sku').nunique()
# Out:
#            name  desc  price  promo_price  in_stock  type
# sku
# AII0013       1     1      1            1         1     1
# APP0390       1     1      1            1         1     1
# APP0574       1     1      1            1         1     1
# APP0624       1     1      1            1         1     1
# APP0733       1     1      1            1         1     1
# ...         ...   ...    ...          ...       ...   ...
# SYN0140       1     1      1            1         1     1
# SYN0141       1     1      1            1         1     1
# SYN0142       1     1      1            1         1     1
# WDT0311-A     1     1      1            1         1     1
# WDT0317       1     1      1            1         1     1
#
# [757 rows x 6 columns]

# %%
'''PLEASE DISCARD THIS CODE SNIPPET, 

WHY: BECAUSE IT DROPPED A LOT OF ROWS AND EVEN WITH ONE SKU CONSIDERING IT AS A DUPLICATE, WHIHC IS NOT THE RIGHT APPROACH. 

THEREFORE I DECIDED TO HAVE ONE ROW PER SKU AND NOT 0 ROWS PER DUPLICATED SKUs

FOR EX, IT DELETED ENTIRELY THAT SKU FROM THE DATAFRAME WHIHC WAS A DUPLICATE, MEANING IF THERE IS AN SKU AP033090 IT DELETED THAT COMPLETELY AND WE DONT WANT THAT

WE WANT THAT SKU BUT ONLY ONES PER ROW'''

#products_df_1 = products_df.drop_duplicates(subset='sku', keep = False)

#products_df_1
# Out:
# 'PLEASE DISCARD THIS CODE SNIPPET, \n\nWHY: BECAUSE IT DROPPED A LOT OF ROWS AND EVEN WITH ONE SKU CONSIDERING IT AS A DUPLICATE, WHIHC IS NOT THE RIGHT APPROACH. \n\nTHEREFORE I DECIDED TO HAVE ONE ROW PER SKU AND NOT 0 ROWS PER DUPLICATED SKUs\n\nFOR EX, IT DELETED ENTIRELY THAT SKU FROM THE DATAFRAME WHIHC WAS A DUPLICATE, MEANING IF THERE IS AN SKU AP033090 IT DELETED THAT COMPLETELY AND WE DONT WANT THAT\n\nWE WANT THAT SKU BUT ONLY ONES PER ROW'

# %% [markdown]
# The code snippet which you see right below, ... this cell has one trick, guess what, i used a parameter keep= 'first' this allows us to safeguard each row per unique skus which is much needed rather than just deleting all skus which are duplicated. So we have now no duplicate skus from the cell below.

# %%
products_df = products_df.drop_duplicates(subset = 'sku', keep = 'first')

products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [10579 rows x 7 columns]

# %% [markdown]
# another step is to remove promo_price column. Why I want to remove promo_price, because it is not adding any useful value, instead creating noise in the dataframe, my golden source of truth to look for discounting strategy lies in the columns price in products_df adn unit_price in orderlines_df

# %%
products_df.isnull().sum()
# Out:
# sku             0
# name            0
# desc            7
# price          45
# promo_price     0
# in_stock        0
# type           50
# dtype: int64

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [10579 rows x 7 columns]

# %%
orderlines_df.isnull().sum()
# Out:
# id                      0
# id_order                0
# product_id              0
# product_quantity        0
# sku                     0
# unit_price          36169
# date                    0
# dtype: int64

# %%
type(completed_orders)
# Out:
# pandas.core.frame.DataFrame

# %%
completed_orders.nunique(), len(completed_orders)
# Out:
# (46605, 46605)

# %%
orderlines_df_completed = orderlines_df.loc[orderlines_df['id_order'].isin(completed_orders)]

# %%
merged_product_orderline_df = orderlines_df_completed.merge(products_df, left_on='sku',right_on='sku',how='left')

merged_product_orderline_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119126    299549           0                 1    PAC0929         NaN
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:07:42  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc  price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...  60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...  22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...     89     649.903
# 3      IMac desktop computer 27 inch Retina 5K RAM 32...   3209  26.679.895
# 4      SSD hard drive and high-speed performance with...  76.99     707.001
# ...                                                  ...    ...         ...
# 62098  velvety inner protective case for MacBook 12 i...  24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...     25      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...     25      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...     25      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...     25      99.898
#
#        in_stock      type
# 0           1.0  12755395
# 1           0.0      5720
# 2           1.0  13005399
# 3           0.0      1282
# 4           0.0      1298
# ...         ...       ...
# 62098       0.0  13835403
# 62099       1.0      1230
# 62100       1.0      1230
# 62101       1.0      1230
# 62102       1.0      1230
#
# [62103 rows x 13 columns]

# %%
#merged_product_orderline_df.drop(['promo_price', 'type'], axis=1, inplace=True)

#merged_product_orderline_df

# %%
merged_product_orderline_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119126    299549           0                 1    PAC0929         NaN
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:07:42  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc    price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...    60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...    22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...    89.00     649.903
# 3      IMac desktop computer 27 inch Retina 5K RAM 32...  3209.00  26.679.895
# 4      SSD hard drive and high-speed performance with...    76.99     707.001
# ...                                                  ...      ...         ...
# 62098  velvety inner protective case for MacBook 12 i...    24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
#
#        in_stock      type  revenue          product_category
# 0           1.0  12755395    47.49                   desktop
# 1           0.0      5720    18.99                     other
# 2           1.0  13005399    72.19           laptop, charger
# 3           0.0      1282      NaN                   desktop
# 4           0.0      1298    60.90                   storage
# ...         ...       ...      ...                       ...
# 62098       0.0  13835403    16.52  laptop, case, protection
# 62099       1.0      1230    19.98                     cable
# 62100       1.0      1230    19.98                     cable
# 62101       1.0      1230    29.97                     cable
# 62102       1.0      1230     9.99                     cable
#
# [62103 rows x 15 columns]

# %%
merged_product_orderline_df['price'] = pd.to_numeric(merged_product_orderline_df['price'], errors= 'coerce')

# %%
merged_product_orderline_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62103 entries, 0 to 62102
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                62103 non-null  int64
#  1   id_order          62103 non-null  int64
#  2   product_id        62103 non-null  int64
#  3   product_quantity  62103 non-null  int64
#  4   sku               62103 non-null  object
#  5   unit_price        58542 non-null  float64
#  6   date              62103 non-null  datetime64[ns]
#  7   name              61742 non-null  object
#  8   desc              61738 non-null  object
#  9   price             60911 non-null  float64
#  10  promo_price       61742 non-null  object
#  11  in_stock          61742 non-null  float64
#  12  type              61729 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 6.2+ MB

# %%
merged_product_orderline_df['revenue'] = merged_product_orderline_df['unit_price']* merged_product_orderline_df['product_quantity']

# %%
merged_product_orderline_df['revenue'].isnull().sum()
# Out:
# np.int64(3561)

# %%
merged_product_orderline_df['unit_price'].isnull().sum()
# Out:
# np.int64(3561)

# %%
(merged_product_orderline_df['revenue'] < 0).sum()
# Out:
# np.int64(0)

# %%
mask = (merged_product_orderline_df['revenue'] == 0) & (merged_product_orderline_df['product_quantity'] > 0)
mask.sum()
# Out:
# np.int64(49)

# %%
merged_product_orderline_df['revenue'].min()
# Out:
# np.float64(0.0)

# %%
merged_product_orderline_df['revenue'].median()
# Out:
# np.float64(69.29)

# %%
merged_product_orderline_df['revenue'].quantile([0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
# 0.25     29.28
# 0.50     69.29
# 0.75    164.99
# 0.95    578.99
# 0.99    899.00
# Name: revenue, dtype: float64

# %%
merged_product_orderline_df['name'].head()
# Out:
# 0    OWC In-line Digital Temperature Sensor Kit HDD...
# 1                 iOttie Easy View 2 Car Black Support
# 2    Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3    Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4                   (Open) Crucial 240GB SSD 7mm BX200
# Name: name, dtype: object

# %%
merged_product_orderline_df['product_category'] = pd.NA

# %%
merged_product_orderline_df['product_category'].isna().sum()
# Out:
# np.int64(62103)

# %% [markdown]
# I will now check to have nay mac_mask items i have and rest sould be NA.

# %%
merged_product_orderline_df['product_category'].value_counts(dropna=False)
# Out:
# product_category
# <NA>    62103
# Name: count, dtype: int64

# %%
#merged_product_orderline_df['name'].isnull().sum()

merged_product_orderline_df['name'].dropna()
# Out:
# 0        OWC In-line Digital Temperature Sensor Kit HDD...
# 1                     iOttie Easy View 2 Car Black Support
# 2        Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3        Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4                       (Open) Crucial 240GB SSD 7mm BX200
#                                ...
# 62098    Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099    Apple Lightning Cable Connector to USB 1m Whit...
# 62100    Apple Lightning Cable Connector to USB 1m Whit...
# 62101    Apple Lightning Cable Connector to USB 1m Whit...
# 62102    Apple Lightning Cable Connector to USB 1m Whit...
# Name: name, Length: 61742, dtype: object

# %%
merged_product_orderline_df.isnull().any()
# Out:
# id                  False
# id_order            False
# product_id          False
# product_quantity    False
# sku                 False
# unit_price           True
# date                False
# name                 True
# desc                 True
# price                True
# promo_price          True
# in_stock             True
# type                 True
# revenue              True
# product_category    False
# dtype: bool

# %% [markdown]
# # Categorization

# %%
# merged_product_orderline_df['product_category'] = merged_product_orderline_df['product_category'].fillna('')

# merged_product_orderline_df.loc[
#     merged_product_orderline_df["name"].str.contains("headphone|earphone|earbud|speaker", case=False, regex=True, na=False),
#     "product_category"
# ] += ", audio"

# merged_product_orderline_df.loc[
#     merged_product_orderline_df["desc"].str.contains("keyboard|mouse|monitor|display|screen", case=False, regex=True, na=False),
#     "product_category"
# ] += ", computer_accessories"


# merged_product_orderline_df.loc[
#     merged_product_orderline_df["name"].str.contains("apple|ipad|macbook|imac|ipod", case=False, regex=True, na=False),
#     "product_category"
# ] += "apple, "


# merged_product_orderline_df.loc[
#     merged_product_orderline_df["desc"].str.contains("ssd|hard drive|hdd|storage|memory card", case=False, regex=True, na=False),
#     "product_category"
# ] += "storage, "


# merged_product_orderline_df.loc[
#     merged_product_orderline_df["desc"].str.contains("gaming|console|controller|playstation|xbox", case=False, regex=True, na=False),
#     "product_category"
# ] += "gaming, "


# merged_product_orderline_df["product_category"] = (
#     merged_product_orderline_df["product_category"]
#     .str.strip(", ")
#     .replace("", "uncategorized")
# )

# %%
merged_product_orderline_df["product_category"] = ""

merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("keyboard", case=False, na=False), "product_category"] += ", keyboard"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple iphone", case=False,na=False), "product_category"] += ", smartphone"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple ipod", case=False,na=False), "product_category"] += ", ipod"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple ipad|tablet", case=False,na=False), "product_category"] += ", tablet"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("imac|desktop|mac mini|mac pro", case=False,na=False), "product_category"] += ", desktop"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("macbook", case=False,na=False), "product_category"] += ", laptop"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("backpack", case=False,na=False), "product_category"] += ", backpack"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("case|funda|housing|casing|folder", case=False,na=False), "product_category"] += ", case"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("dock|hub|connection|expansion box", case=False,na=False), "product_category"] += ", dock"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("cable|connector|lightning to usb|wall socket|power strip", case=False,na=False), "product_category"] += ", cable"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("flash drive|hard drive|pendrive|hard disk|memory|storage|^ssd|^hardssd|modules|ssd expansion", case=False,na=False), "product_category"] = ", storage"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("battery", case=False,na=False), "product_category"] += ", battery"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("headset|headphones", case=False,na=False), "product_category"] += ", headset"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("charger", case=False,na=False), "product_category"] += ", charger"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("mouse|trackpad", case=False,na=False), "product_category"] += ", mouse"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("stand|support", case=False,na=False), "product_category"] += ", stand"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("strap|armband|belt|bracelet", case=False,na=False), "product_category"] += ", strap"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("^.{0,6}apple watch|smartwatch|smart watch", case=False,na=False), "product_category"] += ", smartwatch"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("adapter", case=False,na=False), "product_category"] += ", adapter"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("^.{0,7}ram", case=False,na=False), "product_category"] += ", ram"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("protect|cover|sleeve|screensaver|shell", case=False,na=False), "product_category"] += ", protection"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("nas|server|raid|synology", case=False,na=False), "product_category"] += ", server"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("scale", case=False,na=False), "product_category"] += ", scale"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("thermometer", case=False,na=False), "product_category"] += ", thermometer"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("monitor", case=False,na=False), "product_category"] += ", monitor"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("speaker|music system", case=False,na=False), "product_category"] += ", speaker"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("camera", case=False,na=False), "product_category"] += ", camera"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("pointer", case=False,na=False), "product_category"] += ", pointer"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("refurbished|reconditioned|like new", case=False,na=False), "product_category"] += ", refurbished"

merged_product_orderline_df.loc[merged_product_orderline_df["product_category"] == "", "product_category"] += ", other"

# %%
'''merged_product_orderline_df["name"] = merged_product_orderline_df["name"].fillna("")
merged_product_orderline_df["desc"] = merged_product_orderline_df["desc"].fillna("")'''
# Out:
# 'merged_product_orderline_df["name"] = merged_product_orderline_df["name"].fillna("")\nmerged_product_orderline_df["desc"] = merged_product_orderline_df["desc"].fillna("")'

# %%
'''merged_product_orderline_df["product_category"] = ""
merged_product_orderline_df.loc[(merged_product_orderline_df["name"].str.contains("^.{0,10}apple iphone", case=False))|(merged_product_orderline_df["type"].isin(["1716","85651716","85641716","51601716","113281716","113291716","2481716","24811716","21561716"])), "product_category"] += ", iPhone"
#merged_product_orderline_df.loc[merged_product_orderline_df["type"].isin(["1716","85651716","85641716","51601716","113281716","113291716","2481716","24811716","21561716"]), "product_category"] += ", iPhone"
#merged_product_orderline_df.loc[merged_product_orderline_df["type"]=="1716", "product_category"] += ", iPhone"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("imac|mac mini|mac pro", case=False), "product_category"] += ", iMac"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple ipod", case=False), "product_category"] += ", iPod"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple ipad", case=False), "product_category"] += ", iPad"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("^.{0,6}apple watch|smartwatch|smart watch", case=False), "product_category"] += ", Smartwatch"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("apple tv", case=False), "product_category"] += ", Apple TV"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("apple care", case=False), "product_category"] += ", Apple Care Protection"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}macbook", case=False), "product_category"] += ", MacBook"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("keyboard", case=False), "product_category"] += ", Keyboard"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("case|funda|housing|casing|folder|backpack|back pack", case=False), "product_category"] += ", Case"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("dock|hub|connection|expansion box", case=False), "product_category"] += ", Dock"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("cable|connector|lightning to usb|wall socket|power strip", case=False), "product_category"] += ", Cable"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("flash drive|hard drive|pendrive|hard disk|memory|storage|sata|ssd|^ssd|^hardssd|modules|ssd expansion", case=False), "product_category"] = ", Storage"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("battery", case=False), "product_category"] += ", Battery"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("headset|headphones", case=False), "product_category"] += ", Headset"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("charger", case=False), "product_category"] += ", Charger"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("mouse|trackpad", case=False), "product_category"] += ", Mouse"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("protect|cover|sleeve|screensaver|shell|glass|glare", case=False), "product_category"] += ", Protection"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("nas|server|raid|synology", case=False), "product_category"] += ", Server"
merged_product_orderline_df.loc[(merged_product_orderline_df["desc"].str.contains("stand|support|table", case=False))|(merged_product_orderline_df["name"].str.contains("stand|support|table", case=False)), "product_category"] += ", Stand"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("monitor|LCD", case=False), "product_category"] += ", Monitor"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("speaker|music system", case=False), "product_category"] += ", Speaker"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("camera|lens", case=False), "product_category"] += ", Camera"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("pointer", case=False), "product_category"] += ", Pointer"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("refurbished|reconditioned|like new", case=False), "product_category"] += ", Refurbished"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("repair|service|screwdriver|screw driver|replacement", case=False), "product_category"] += ", Tools, Serice & Repair"
merged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("blood pressure|bloodpressure", case=False), "product_category"] += ", Health care"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("strap|armband|belt|bracelet", case=False), "product_category"] += ", Strap"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("adapter", case=False), "product_category"] += ", Adapter"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("^.{0,7}ram", case=False), "product_category"] += ", Ram"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("scale", case=False), "product_category"] += ", Scale"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("thermometer", case=False), "product_category"] += ", Thermometer"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("stylus|pencil", case=False), "product_category"] += ", Stylus"
merged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("port|ethernet|router", case=False), "product_category"] += ", Extension Ports"
merged_product_orderline_df.loc[merged_product_orderline_df['product_category']=="","product_category"]+=", Others"'''
# Out:
# 'merged_product_orderline_df["product_category"] = ""\nmerged_product_orderline_df.loc[(merged_product_orderline_df["name"].str.contains("^.{0,10}apple iphone", case=False))|(merged_product_orderline_df["type"].isin(["1716","85651716","85641716","51601716","113281716","113291716","2481716","24811716","21561716"])), "product_category"] += ", iPhone"\n#merged_product_orderline_df.loc[merged_product_orderline_df["type"].isin(["1716","85651716","85641716","51601716","113281716","113291716","2481716","24811716","21561716"]), "product_category"] += ", iPhone"\n#merged_product_orderline_df.loc[merged_product_orderline_df["type"]=="1716", "product_category"] += ", iPhone"\nmerged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("imac|mac mini|mac pro", case=False), "product_category"] += ", iMac"\nmerged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple ipod", case=False), "product_category"] += ", iPod"\nmerged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}apple ipad", case=False), "product_category"] += ", iPad"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("^.{0,6}apple watch|smartwatch|smart watch", case=False), "product_category"] += ", Smartwatch"\nmerged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("apple tv", case=False), "product_category"] += ", Apple TV"\nmerged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("apple care", case=False), "product_category"] += ", Apple Care Protection"\nmerged_product_orderline_df.loc[merged_product_orderline_df["name"].str.contains("^.{0,7}macbook", case=False), "product_category"] += ", MacBook"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("keyboard", case=False), "product_category"] += ", Keyboard"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("case|funda|housing|casing|folder|backpack|back pack", case=False), "product_category"] += ", Case"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("dock|hub|connection|expansion box", case=False), "product_category"] += ", Dock"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("cable|connector|lightning to usb|wall socket|power strip", case=False), "product_category"] += ", Cable"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("flash drive|hard drive|pendrive|hard disk|memory|storage|sata|ssd|^ssd|^hardssd|modules|ssd expansion", case=False), "product_category"] = ", Storage"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("battery", case=False), "product_category"] += ", Battery"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("headset|headphones", case=False), "product_category"] += ", Headset"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("charger", case=False), "product_category"] += ", Charger"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("mouse|trackpad", case=False), "product_category"] += ", Mouse"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("protect|cover|sleeve|screensaver|shell|glass|glare", case=False), "product_category"] += ", Protection"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("nas|server|raid|synology", case=False), "product_category"] += ", Server"\nmerged_product_orderline_df.loc[(merged_product_orderline_df["desc"].str.contains("stand|support|table", case=False))|(merged_product_orderline_df["name"].str.contains("stand|support|table", case=False)), "product_category"] += ", Stand"\nmerged_product_orderline_df.loc[merged_product_orderline_df["desc"].str.contains("monitor|LCD", case=False), "product_category"] += ", Monitor"\nmerged_product_orderline_df.loc[ ...

# %%
#merged_product_orderline_df['product_category']=merged_product_orderline_df['product_category'].str[2:]
#merged_product_orderline_df

# %%
merged_product_orderline_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119126    299549           0                 1    PAC0929         NaN
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:07:42  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc    price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...    60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...    22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...    89.00     649.903
# 3      IMac desktop computer 27 inch Retina 5K RAM 32...  3209.00  26.679.895
# 4      SSD hard drive and high-speed performance with...    76.99     707.001
# ...                                                  ...      ...         ...
# 62098  velvety inner protective case for MacBook 12 i...    24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
#
#        in_stock      type  revenue            product_category
# 0           1.0  12755395    47.49                   , desktop
# 1           0.0      5720    18.99                     , other
# 2           1.0  13005399    72.19           , laptop, charger
# 3           0.0      1282      NaN                   , desktop
# 4           0.0      1298    60.90                   , storage
# ...         ...       ...      ...                         ...
# 62098       0.0  13835403    16.52  , laptop, case, protection
# 62099       1.0      1230    19.98                     , cable
# 62100       1.0      1230    19.98                     , cable
# 62101       1.0      1230    29.97                     , cable
# 62102       1.0      1230     9.99                     , cable
#
# [62103 rows x 15 columns]

# %% [markdown]
# # Please dont use the code below

# %%
'''for i in range(len(merged_product_orderline_df)):
    cat = merged_product_orderline_df.at[i, 'product_category']
    cat = cat.strip()
    import re
    cat = re.sub(r'\b(\w+)\1\b', r'\1', cat)  #  i took from llm
    

    words = cat.split(',')
    words = [w.strip().capitalize() for w in words if w.strip()] 
    words = sorted(set(words))
    
    merged_product_orderline_df.at[i, 'product_category'] = ', '.join(words)'''
# Out:
# "for i in range(len(merged_product_orderline_df)):\n    cat = merged_product_orderline_df.at[i, 'product_category']\n    cat = cat.strip()\n    import re\n    cat = re.sub(r'\x08(\\w+)\x01\x08', r'\x01', cat)  #  i took from llm\n    \n\n    words = cat.split(',')\n    words = [w.strip().capitalize() for w in words if w.strip()] \n    words = sorted(set(words))\n    \n    merged_product_orderline_df.at[i, 'product_category'] = ', '.join(words)"

# %%
merged_product_orderline_df['product_category'].head()
# Out:
# 0            , desktop
# 1              , other
# 2    , laptop, charger
# 3            , desktop
# 4            , storage
# Name: product_category, dtype: object

# %%
state_mask = orders_df['state'] == 'Completed'
completed_orders = orders_df.loc[state_mask, 'order_id'] 

completed_revenue_df = merged_product_orderline_df[merged_product_orderline_df['id_order'].isin(completed_orders)]

completed_revenue_df.shape
# Out:
# (62103, 15)

# %% [markdown]
# # please dont follow the below code

# %%
#completed_revenue_df['order_month'] = completed_revenue_df['date'].dt.to_period('M')

# %%
completed_revenue_df = merged_product_orderline_df[merged_product_orderline_df['id_order'].isin(completed_orders)].copy()
completed_revenue_df['order_month'] = completed_revenue_df['date'].dt.to_period('M')

completed_revenue_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119126    299549           0                 1    PAC0929         NaN
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:07:42  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc    price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...    60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...    22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...    89.00     649.903
# 3      IMac desktop computer 27 inch Retina 5K RAM 32...  3209.00  26.679.895
# 4      SSD hard drive and high-speed performance with...    76.99     707.001
# ...                                                  ...      ...         ...
# 62098  velvety inner protective case for MacBook 12 i...    24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
#
#        in_stock      type  revenue            product_category order_month
# 0           1.0  12755395    47.49                   , desktop     2017-01
# 1           0.0      5720    18.99                     , other     2017-01
# 2           1.0  13005399    72.19           , laptop, charger     2017-01
# 3           0.0      1282      NaN                   , desktop     2017-01
# 4           0.0      1298    60.90                   , storage     2017-01
# ...         ...       ...      ...                         ...         ...
# 62098       0.0  13835403    16.52  , laptop, case, protection     2018-03
# 62099       1.0      1230    19.98                     , cable     2018-03
# 62100       1.0      1230    19.98                     , cable     2018-03
# 62101       1.0      1230    29.97                     , cable     2018-03
# 62102       1.0      1230     9.99                     , cable     2018-03
#
# [62103 rows x 16 columns]

# %%
category_monthly_revenue_df = completed_revenue_df.groupby(['order_month', 'product_category'])['revenue'].sum().reset_index().sort_values(['order_month', 'revenue'], ascending=[True, False])

category_monthly_revenue_df.head(20)
# Out:
#     order_month        product_category    revenue
# 102     2017-01               , storage  134438.63
# 85      2017-01                 , other   75169.87
# 109     2017-01                , tablet   45025.92
# 89      2017-01                   , ram   44759.64
# 105     2017-01       , storage, server   43047.46
# 80      2017-01               , monitor   42419.87
# 94      2017-01            , smartphone   36951.74
# 93      2017-01                , server   34564.72
# 41      2017-01  , dock, cable, monitor   24066.61
# 28      2017-01               , desktop   18583.73
# 62      2017-01                , laptop   14318.94
# 97      2017-01            , smartwatch   10073.63
# 0       2017-01               , adapter    8568.28
# 66      2017-01       , laptop, battery    8332.42
# 49      2017-01               , headset    8293.29
# 35      2017-01                  , dock    7398.26
# 7       2017-01                 , cable    7314.21
# 19      2017-01                  , case    6859.54
# 70      2017-01       , laptop, charger    6740.27
# 98      2017-01               , speaker    6730.22

# %%
category_monthly_revenue_df.agg(max)
# Out:
# /var/folders/mm/g2sl_2xx3xs60cq6qv_2ssxh0000gn/T/ipykernel_10800/520674349.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrame.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   category_monthly_revenue_df.agg(max)
# order_month               2018-03
# product_category    , thermometer
# revenue                 247160.92
# dtype: object

# %%
merged_product_orderline_df.shape
merged_product_orderline_df['product_category'].value_counts().head(10)
merged_product_orderline_df[['date', 'revenue', 'product_category']].head()
# Out:
#                  date  revenue   product_category
# 0 2017-01-01 01:46:16    47.49          , desktop
# 1 2017-01-01 01:50:34    18.99            , other
# 2 2017-01-01 01:54:11    72.19  , laptop, charger
# 3 2017-01-01 02:07:42      NaN          , desktop
# 4 2017-01-01 02:20:14    60.90          , storage

# %%
for i in range(len(merged_product_orderline_df)):
    cat = merged_product_orderline_df.at[i, 'product_category']
    if isinstance(cat, str):
        merged_product_orderline_df.at[i, 'product_category'] = cat.lstrip(', ').strip()


merged_product_orderline_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119126    299549           0                 1    PAC0929         NaN
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:07:42  Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc    price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...    60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...    22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...    89.00     649.903
# 3      IMac desktop computer 27 inch Retina 5K RAM 32...  3209.00  26.679.895
# 4      SSD hard drive and high-speed performance with...    76.99     707.001
# ...                                                  ...      ...         ...
# 62098  velvety inner protective case for MacBook 12 i...    24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...    25.00      99.898
#
#        in_stock      type  revenue          product_category
# 0           1.0  12755395    47.49                   desktop
# 1           0.0      5720    18.99                     other
# 2           1.0  13005399    72.19           laptop, charger
# 3           0.0      1282      NaN                   desktop
# 4           0.0      1298    60.90                   storage
# ...         ...       ...      ...                       ...
# 62098       0.0  13835403    16.52  laptop, case, protection
# 62099       1.0      1230    19.98                     cable
# 62100       1.0      1230    19.98                     cable
# 62101       1.0      1230    29.97                     cable
# 62102       1.0      1230     9.99                     cable
#
# [62103 rows x 15 columns]

# %%
merged_product_orderline_df.columns
# Out:
# Index(['id', 'id_order', 'product_id', 'product_quantity', 'sku', 'unit_price',
#        'date', 'name', 'desc', 'price', 'promo_price', 'in_stock', 'type',
#        'revenue', 'product_category'],
#       dtype='object')

# %%
analysis_df = merged_product_orderline_df.dropna(subset=['revenue', 'unit_price', 'price']).copy()

# %%
analysis_df.isnull().sum()
# Out:
# id                   0
# id_order             0
# product_id           0
# product_quantity     0
# sku                  0
# unit_price           0
# date                 0
# name                 0
# desc                 0
# price                0
# promo_price          0
# in_stock             0
# type                13
# revenue              0
# product_category     0
# dtype: int64

# %%
analysis_df['year'] = analysis_df['date'].dt.year

# %%
analysis_df['month'] = analysis_df['date'].dt.month

# %%
analysis_df.groupby(['year', 'month'])['revenue'].sum()
# Out:
# year  month
# 2017  1         642773.67
#       2         341631.74
#       3          28615.51
#       4         250647.66
#       5         361518.55
#       6         315670.56
#       7         639950.29
#       8         401223.71
#       9         417494.56
#       10        590835.81
#       11       1612476.22
#       12       1049251.34
# 2018  1         915411.44
#       2         562171.54
#       3         234943.68
# Name: revenue, dtype: float64

# %%
analysis_df['order_month'] = analysis_df['date'].dt.to_period('M')

# %%
#analysis_df.groupby(['order_month', 'product_category'])['revenue'].sum()
analysis_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# 5      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# 5     2017-01-01 02:38:50                 Pebble Smartwatch Time Steel Black
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc   price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...   60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...   22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...   89.00     649.903
# 4      SSD hard drive and high-speed performance with...   76.99     707.001
# 5      Bluetooth Smart Watch with steel case leather ...  299.99   1.229.905
# ...                                                  ...     ...         ...
# 62098  velvety inner protective case for MacBook 12 i...   24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
#
#        in_stock      type  revenue          product_category  year  month  \
# 0           1.0  12755395    47.49                   desktop  2017      1
# 1           0.0      5720    18.99                     other  2017      1
# 2           1.0  13005399    72.19           laptop, charger  2017      1
# 4           0.0      1298    60.90                   storage  2017      1
# 5           0.0  11905404   142.49   case, strap, smartwatch  2017      1
# ...         ...       ...      ...                       ...   ...    ...
# 62098       0.0  13835403    16.52  laptop, case, protection  2018      3
# 62099       1.0      1230    19.98                     cable  2018      3
# 62100       1.0      1230    19.98                     cable  2018      3
# 62101       1.0      1230    29.97                     cable  2018      3
# 62102       1.0      1230     9.99                     cable  2018      3
#
#       order_month
# 0         2017-01
# 1         2017-01
# 2         2017-01
# 4         2017-01
# 5         2017-01
# ...           ...
# 62098     2018-03
# 62099     2018-03
# 62100     2018-03
# 62101     2018-03
# 62102     2018-03
#
# [57583 rows x 18 columns]

# %%
monthly_category_revenue = (analysis_df.groupby(['order_month', 'product_category'])['revenue'].sum().reset_index())

# %%
monthly_category_revenue
# Out:
#      order_month          product_category   revenue
# 0        2017-01                   adapter   8568.28
# 1        2017-01      adapter, refurbished      6.50
# 2        2017-01                   battery   5830.27
# 3        2017-01          battery, charger     69.99
# 4        2017-01          battery, headset    556.95
# ...          ...                       ...       ...
# 1729     2018-03                    tablet  10344.61
# 1730     2018-03  tablet, case, protection    111.00
# 1731     2018-03           tablet, pointer   2389.94
# 1732     2018-03        tablet, protection    333.98
# 1733     2018-03               thermometer     32.99
#
# [1734 rows x 3 columns]

# %%
heatmap_data = monthly_category_revenue.pivot(index = 'product_category', columns = 'order_month', values = 'revenue')

# %%
plt.figure(figsize=(14, 8))

sns.heatmap(
    heatmap_data,
    cmap='YlOrRd',
    linewidths=0.5
)

plt.title('Monthly Revenue by Product Category')
plt.xlabel('Order Month')
plt.ylabel('Product Category')

plt.tight_layout()
plt.show()

# %%
analysis_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 4      1119134    299556           0                 1  CRU0039-A       60.90
# 5      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 62098  1649474    525664           0                 1    TUC0207       16.52
# 62099  1649512    527070           0                 2    APP0698        9.99
# 62100  1649522    527074           0                 2    APP0698        9.99
# 62101  1649565    527096           0                 3    APP0698        9.99
# 62102  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 4     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# 5     2017-01-01 02:38:50                 Pebble Smartwatch Time Steel Black
# ...                   ...                                                ...
# 62098 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 62099 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 62100 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 62101 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 62102 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc   price promo_price  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...   60.99     499.899
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...   22.95     169.896
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...   89.00     649.903
# 4      SSD hard drive and high-speed performance with...   76.99     707.001
# 5      Bluetooth Smart Watch with steel case leather ...  299.99   1.229.905
# ...                                                  ...     ...         ...
# 62098  velvety inner protective case for MacBook 12 i...   24.99     199.904
# 62099  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
# 62100  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
# 62101  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
# 62102  Apple Lightning USB Cable 1 meter to charge an...   25.00      99.898
#
#        in_stock      type  revenue          product_category  year  month  \
# 0           1.0  12755395    47.49                   desktop  2017      1
# 1           0.0      5720    18.99                     other  2017      1
# 2           1.0  13005399    72.19           laptop, charger  2017      1
# 4           0.0      1298    60.90                   storage  2017      1
# 5           0.0  11905404   142.49   case, strap, smartwatch  2017      1
# ...         ...       ...      ...                       ...   ...    ...
# 62098       0.0  13835403    16.52  laptop, case, protection  2018      3
# 62099       1.0      1230    19.98                     cable  2018      3
# 62100       1.0      1230    19.98                     cable  2018      3
# 62101       1.0      1230    29.97                     cable  2018      3
# 62102       1.0      1230     9.99                     cable  2018      3
#
#       order_month
# 0         2017-01
# 1         2017-01
# 2         2017-01
# 4         2017-01
# 5         2017-01
# ...           ...
# 62098     2018-03
# 62099     2018-03
# 62100     2018-03
# 62101     2018-03
# 62102     2018-03
#
# [57583 rows x 18 columns]

# %%
brands_df.value_counts().sum()
# Out:
# np.int64(187)

# %%
brands_df.head(20)
# Out:
#    short              long
# 0    8MO         8Mobility
# 1    ACM              Acme
# 2    ADN            Adonit
# 3    AII             Aiino
# 4    AKI            Akitio
# 5    ALL         Allocacoc
# 6    AP2             Apple
# 7    APP             Apple
# 8    BAN        Band&Strap
# 9    BEA             Beats
# 10   BEL            Belkin
# 11   BEZ             Be.ez
# 12   BLL        BlueLounge
# 13   BLM  Blue Microphones
# 14   BNQ              BenQ
# 15   BOD        BodyGuardz
# 16   BOO              Booq
# 17   BOS              Bose
# 18   BTC         Boostcase
# 19   CAD              Bose

# %%
analysis_df = analysis_df.merge(brands_df.rename(columns={'short': 'type', 'long': 'brand_name'}),on='type',how='left')

# %%
analysis_df.head(5)
# Out:
#         id  id_order  product_id  product_quantity        sku  unit_price  \
# 0  1119116    299545           0                 1    OWC0100       47.49
# 1  1119119    299546           0                 1    IOT0014       18.99
# 2  1119120    295347           0                 1    APP0700       72.19
# 3  1119134    299556           0                 1  CRU0039-A       60.90
# 4  1119145    299561           0                 1    PEB0015      142.49
#
#                  date                                               name  \
# 0 2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1 2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2 2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3 2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# 4 2017-01-01 02:38:50                 Pebble Smartwatch Time Steel Black
#
#                                                 desc   price promo_price  \
# 0  Kit temperature sensor for HDD iMac 21 inch an...   60.99     499.899
# 1  IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...   22.95     169.896
# 2  Apple MagSafe 2 Charger for MacBook Pro 15-inc...   89.00     649.903
# 3  SSD hard drive and high-speed performance with...   76.99     707.001
# 4  Bluetooth Smart Watch with steel case leather ...  299.99   1.229.905
#
#    in_stock      type  revenue         product_category  year  month  \
# 0       1.0  12755395    47.49                  desktop  2017      1
# 1       0.0      5720    18.99                    other  2017      1
# 2       1.0  13005399    72.19          laptop, charger  2017      1
# 3       0.0      1298    60.90                  storage  2017      1
# 4       0.0  11905404   142.49  case, strap, smartwatch  2017      1
#
#   order_month brand_name
# 0     2017-01        NaN
# 1     2017-01        NaN
# 2     2017-01        NaN
# 3     2017-01        NaN
# 4     2017-01        NaN

# %%
brands_df
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %%
analysis_df['brand_code'] = analysis_df['type'].str[:3]
analysis_df[['type', 'brand_code']].head(10)
# Out:
#        type brand_code
# 0  12755395        127
# 1      5720        572
# 2  13005399        130
# 3      1298        129
# 4  11905404        119
# 5      5384        538
# 6      1387        138
# 7  12175397        121
# 8      5398        539
# 9      1296        129

# %%
set(analysis_df['brand_code'].unique()) & set(brands_df['short'].unique())
# Out:
# set()

# %%
analysis_df['brand_code'] = analysis_df['type'].str[:3]
brands_df_renamed = brands_df.rename(columns={'short': 'brand_code', 'long': 'brand_name'})

analysis_df = analysis_df.merge(brands_df_renamed, on='brand_code', how='left')
analysis_df[['type', 'brand_code', 'brand_name']].head(10)
# Out:
#        type brand_code brand_name
# 0  12755395        127        NaN
# 1      5720        572        NaN
# 2  13005399        130        NaN
# 3      1298        129        NaN
# 4  11905404        119        NaN
# 5      5384        538        NaN
# 6      1387        138        NaN
# 7  12175397        121        NaN
# 8      5398        539        NaN
# 9      1296        129        NaN

# %%
if 'brand_name' in analysis_df.columns:
    analysis_df.drop(columns=['brand_name'], inplace=True)

# %%
analysis_df['brand_code'] = analysis_df['sku'].str[:3]

brands_df_renamed = brands_df.rename(columns={'short': 'brand_code', 'long': 'brand_name'})

analysis_df = analysis_df.merge(brands_df_renamed, on='brand_code', how='left')
analysis_df[['sku', 'brand_code', 'brand_name']].head(10)
# Out:
#          sku brand_code brand_name
# 0    OWC0100        OWC        OWC
# 1    IOT0014        IOT     iOttie
# 2    APP0700        APP      Apple
# 3  CRU0039-A        CRU    Crucial
# 4    PEB0015        PEB     Pebble
# 5    BEA0065        BEA      Beats
# 6    SAT0010        SAT    Satechi
# 7    SYN0139        SYN   Synology
# 8    LOG0191        LOG   Logitech
# 9  LGE0031-A        LGE         LG

# %%
category_brand_price = analysis_df.groupby(['product_category', 'brand_name'])['unit_price'].mean().reset_index().sort_values(['product_category', 'unit_price'], ascending=[True, False])

category_product_price = analysis_df.groupby(['product_category', 'name'])['unit_price'].mean().reset_index().sort_values(['product_category', 'unit_price'], ascending=[True, False])

# %%
brand_avg_price = analysis_df.groupby('brand_name', as_index=False)['unit_price'].mean().sort_values('unit_price', ascending=False).head(10)

brand_avg_price
# Out:
#      brand_name  unit_price
# 30         Eizo  625.786471
# 29        Drobo  490.693333
# 95      Ninebot  464.027049
# 66           LG  420.621565
# 11         BenQ  390.864540
# 25         Dell  364.642789
# 138       Sonos  361.562161
# 118        QNAP  354.885000
# 41   Glyph Atom  311.236190
# 146    Synology  311.151974

# %%
plt.figure(figsize=(8, 4))

palette = sns.color_palette("flare", n_colors=len(brand_avg_price))

sns.barplot(
    data=brand_avg_price,
    x='unit_price',
    y='brand_name',
    palette=palette
)

plt.title('Top 10 Brands by Average Selling Price')
plt.xlabel('Average Unit Price')
plt.ylabel('Brand')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/mm/g2sl_2xx3xs60cq6qv_2ssxh0000gn/T/ipykernel_10800/2282375766.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
category_avg_price = (analysis_df.groupby('product_category', as_index=False)['unit_price'].mean().sort_values('unit_price', ascending=False).head(10))

category_avg_price
# Out:
#                         product_category  unit_price
# 212                         tablet, dock  857.343143
# 147                  laptop, refurbished  786.859063
# 154        monitor, speaker, refurbished  739.910000
# 200               storage, server, scale  587.146667
# 170                           smartphone  575.865797
# 201  storage, server, scale, refurbished  557.070000
# 63                  desktop, refurbished  551.700909
# 152                 monitor, refurbished  518.326667
# 215                  tablet, refurbished  513.668750
# 76                  dock, cable, monitor  508.413110

# %%
analysis_df.loc[analysis_df['product_category'] == 'desktop, refurbished', ['unit_price', 'price']].describe()
# Out:
#        unit_price        price
# count   66.000000    66.000000
# mean   551.700909  1220.818182
# std    257.297463   237.932822
# min    240.260000   599.000000
# 25%    291.772500  1199.000000
# 50%    467.295000  1199.000000
# 75%    813.835000  1279.000000
# max    978.990000  1799.000000

# %%
category_avg_price1 = (analysis_df.groupby('product_category', as_index=False)['price'].mean().sort_values('price', ascending=False).head(10))

category_avg_price1
# Out:
#                      product_category        price
# 63               desktop, refurbished  1220.818182
# 212                      tablet, dock  1099.900000
# 147               laptop, refurbished  1027.384687
# 129      laptop, battery, refurbished   999.896000
# 154     monitor, speaker, refurbished   989.990000
# 52   case, strap, smartwatch, monitor   898.545455
# 48   case, stand, smartwatch, monitor   869.000000
# 44          case, smartwatch, monitor   869.000000
# 40                      case, pointer   799.895000
# 152              monitor, refurbished   688.830000

# %%
plt.figure(figsize=(8, 4))
palette = sns.color_palette("flare", n_colors=len(category_avg_price))

sns.barplot(
    data=category_avg_price,
    x='unit_price',
    y='product_category', hue='product_category',
    palette=palette
)

plt.title('Top 10 Product Categories by Average Unit Price')
plt.xlabel('Average Unit Price')
plt.ylabel('Product Category')

plt.tight_layout()
plt.show()

# %%
analysis_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 57578  1649474    525664           0                 1    TUC0207       16.52
# 57579  1649512    527070           0                 2    APP0698        9.99
# 57580  1649522    527074           0                 2    APP0698        9.99
# 57581  1649565    527096           0                 3    APP0698        9.99
# 57582  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# 4     2017-01-01 02:38:50                 Pebble Smartwatch Time Steel Black
# ...                   ...                                                ...
# 57578 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 57579 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 57580 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 57581 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 57582 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc   price  ...  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...   60.99  ...
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...   22.95  ...
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...   89.00  ...
# 3      SSD hard drive and high-speed performance with...   76.99  ...
# 4      Bluetooth Smart Watch with steel case leather ...  299.99  ...
# ...                                                  ...     ...  ...
# 57578  velvety inner protective case for MacBook 12 i...   24.99  ...
# 57579  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...
# 57580  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...
# 57581  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...
# 57582  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...
#
#            type  revenue          product_category  year month  order_month  \
# 0      12755395    47.49                   desktop  2017     1      2017-01
# 1          5720    18.99                     other  2017     1      2017-01
# 2      13005399    72.19           laptop, charger  2017     1      2017-01
# 3          1298    60.90                   storage  2017     1      2017-01
# 4      11905404   142.49   case, strap, smartwatch  2017     1      2017-01
# ...         ...      ...                       ...   ...   ...          ...
# 57578  13835403    16.52  laptop, case, protection  2018     3      2018-03
# 57579      1230    19.98                     cable  2018     3      2018-03
# 57580      1230    19.98                     cable  2018     3      2018-03
# 57581      1230    29.97                     cable  2018     3      2018-03
# 57582      1230     9.99                     cable  2018     3      2018-03
#
#        brand_name_x brand_code brand_name_y brand_name
# 0               NaN        OWC          NaN        OWC
# 1               NaN        IOT          NaN     iOttie
# 2               NaN        APP          NaN      Apple
# 3               NaN        CRU          NaN    Crucial
# 4               NaN        PEB          NaN     Pebble
# ...             ...        ...          ...        ...
# 57578           NaN        TUC          NaN     Tucano
# 57579           NaN        APP          NaN      Apple
# 57580           NaN        APP          NaN      Apple
# 57581           NaN        APP          NaN      Apple
# 57582           NaN        APP          NaN      Apple
#
# [57583 rows x 22 columns]

# %%
top10_brands = analysis_df.groupby('brand_name', as_index=False)['revenue'].sum().sort_values('revenue', ascending=False).head(10)

top10_brands
# Out:
#           brand_name     revenue
# 6              Apple  2792223.06
# 108             Pack   503677.10
# 101              OWC   481875.18
# 68             LaCie   477824.12
# 163  Western Digital   389560.64
# 66                LG   342276.83
# 20           Crucial   299061.91
# 162            Wacom   289071.45
# 25              Dell   277065.40
# 146         Synology   176931.53

# %%
brand_price_summary = (analysis_df[analysis_df['brand_name'].isin(top10_brands['brand_name'])].groupby('brand_name').agg(avg_list_price=('price', 'mean'),avg_selling_price=('unit_price', 'mean')).reset_index())

brand_price_summary
# Out:
#         brand_name  avg_list_price  avg_selling_price
# 0            Apple      268.715636         240.629670
# 1          Crucial      187.384745         138.866672
# 2             Dell      444.342520         364.642789
# 3               LG      468.935497         420.621565
# 4            LaCie      242.864105         216.653661
# 5              OWC      153.579188         123.241190
# 6             Pack      394.434514         275.189186
# 7         Synology      321.232569         311.151974
# 8            Wacom      205.473581         158.973396
# 9  Western Digital      185.128099         150.338822

# %%
plt.figure(figsize=(10, 5))

brand_price_summary_melted = brand_price_summary.melt(
    id_vars='brand_name',
    value_vars=['avg_list_price', 'avg_selling_price'],
    var_name='price_type',
    value_name='price'
)

sns.barplot(
    data=brand_price_summary_melted,
    y='brand_name',
    x='price',
    hue='price_type'
)

plt.title('Top 10 Brands: List Price vs Selling Price')
plt.xlabel('Average Price')
plt.ylabel('Brand')
plt.legend(title='')
plt.tight_layout()
plt.show()

# %%
analysis_df['discount_pct'] = (analysis_df['price'] - analysis_df['unit_price']) / analysis_df['price'] 

brand_metrics = (
    analysis_df
    .groupby('brand_name')
    .agg(
        total_revenue=('revenue', 'sum'),
        total_units=('product_quantity', 'sum'),
        avg_price=('unit_price', 'mean'),
        avg_discount_pct=('discount_pct', 'mean')
    )
    .reset_index()
)

# %%
top_margin_brands = (
    brand_metrics
    .sort_values('avg_discount_pct')
    .head(10)
)

top_margin_brands
# Out:
#       brand_name  total_revenue  total_units   avg_price  avg_discount_pct
# 121       Repair        8629.78          109   79.172294         -0.034788
# 11          BenQ       71378.66          186  390.864540         -0.009576
# 89         MyFox         199.99            1  199.990000          0.000000
# 60   Kaiser Baas          88.99            1   88.990000          0.000112
# 126      SDesign        1229.82           18   68.225294          0.025214
# 146     Synology      176931.53          575  311.151974          0.029875
# 76      Maclocks         714.40           11   68.546667          0.030777
# 46   Henge Docks        5916.25           70   84.062794          0.044856
# 115        Prynt        3883.32           53   76.489400          0.048807
# 69   LandingZone        2948.16           14  207.551538          0.055334

# %%
top10_revenue_brands = brand_metrics.sort_values('total_revenue', ascending=False).head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14,8))

# Scatter: X=avg_price, Y=total_units, Size=Revenue, Color=Discount
scatter = sns.scatterplot(
    data=brand_metrics,
    x='avg_price',
    y='total_units',
    size='total_revenue',
    hue='avg_discount_pct',
    palette='coolwarm_r',  # red = high discount
    sizes=(100, 2000),
    alpha=0.8,
    edgecolor='k'
)

# Annotate top 5 revenue brands
for _, row in top10_revenue_brands.iterrows():
    plt.text(
        row['avg_price']*1.01, row['total_units']*1.01, 
        row['brand_name'], 
        horizontalalignment='left', 
        size='medium', 
        color='black', 
        weight='semibold'
    )

# Labels, titles, legend
plt.title('Brand Performance: Units vs Price with Revenue & Discount', fontsize=16)
plt.xlabel('Average Unit Price')
plt.ylabel('Total Units Sold')
plt.legend(title='Discount % (color)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
analysis_df.loc[analysis_df['product_category'].str.contains('desktop')]
# Out:
#             id  id_order  product_id  product_quantity      sku  unit_price  \
# 0      1119116    299545           0                 1  OWC0100       47.49
# 22     1119299    298391           0                 1  APP0662      149.99
# 28     1119328    297809           0                 1  IFX0016       14.24
# 35     1119404    299673           0                 1  PAC0569      168.14
# 81     1119814    299891           0                 1  OWC0186       56.99
# ...        ...       ...         ...               ...      ...         ...
# 57400  1647575    526129           0                 1  IFX0028       19.99
# 57446  1648040    526319           0                 1  OWC0053       21.99
# 57457  1648121    526360           0                 1  IFX0027       26.00
# 57459  1648138    526367           0                 1  IFX0028       19.99
# 57489  1648365    526466           0                 1  SOF0131       74.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 22    2017-01-01 11:41:58                     IMac AppleCare Protection Plan
# 28    2017-01-01 12:01:12  iFixit Heavy Duty Suction Cups Pack 2 suction ...
# 35    2017-01-01 12:56:10  Samsung 256GB SSD expansion PRO Kit for iMac 2...
# 81    2017-01-01 19:25:47  OWC Accelsior S Adapter PCIe 2.5 "Sata 6Gb / s...
# ...                   ...                                                ...
# 57400 2018-03-12 20:12:44  iFixit Kit adhesive strips for iMac 27 "EMC an...
# 57446 2018-03-13 10:45:51  OWC SSD installation Kit for iMac 215 "(2011) ...
# 57457 2018-03-13 11:38:58      iFixit adhesive strips Kit for iMac 21.5 "EMC
# 57459 2018-03-13 11:47:51  iFixit Kit adhesive strips for iMac 27 "EMC an...
# 57489 2018-03-13 14:37:02                           Mac Parallels Desktop 13
#
#                                                     desc   price  ... revenue  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...   60.99  ...   47.49
# 22                Apple Care extended warranty for iMac.  179.00  ...  149.99
# 28     Pack of 2 suction to remove the glass LCD scre...   20.99  ...   14.24
# 35           Upgrade kit 256GB SSD iMac 27 inch Mid 2011  200.98  ...  168.14
# 81     PCI Express SSD for Mac Pro up to 51 (mid 2006...   78.99  ...   56.99
# ...                                                  ...     ...  ...     ...
# 57400           Kit adhesive strips for an iMac 27 inch.   19.99  ...   19.99
# 57446  Kit installation without tools iMac SSD 215 in...   35.99  ...   21.99
# 57457           Kit adhesive strips for iMac 215 inches.   26.00  ...   26.00
# 57459           Kit adhesive strips for an iMac 27 inch.   19.99  ...   19.99
# 57489  The easiest and fastest way to run Windows on ...   79.99  ...   74.99
#
#        product_category  year  month order_month  brand_name_x  brand_code  \
# 0               desktop  2017      1     2017-01           NaN         OWC
# 22              desktop  2017      1     2017-01           NaN         APP
# 28              desktop  2017      1     2017-01           NaN         IFX
# 35              desktop  2017      1     2017-01           NaN         PAC
# 81              desktop  2017      1     2017-01           NaN         OWC
# ...                 ...   ...    ...         ...           ...         ...
# 57400           desktop  2018      3     2018-03           NaN         IFX
# 57446           desktop  2018      3     2018-03           NaN         OWC
# 57457           desktop  2018      3     2018-03           NaN         IFX
# 57459           desktop  2018      3     2018-03           NaN         IFX
# 57489           desktop  2018      3     2018-03           NaN         SOF
#
#       brand_name_y brand_name discount_pct
# 0              NaN        OWC     0.221348
# 22             NaN      Apple     0.162067
# 28             NaN     iFixit     0.321582
# 35             NaN       Pack     0.163399
# 81             NaN        OWC     0.278516
# ...            ...        ...          ...
# 57400          NaN     iFixit     0.000000
# 57446          NaN        OWC     0.388997
# 57457          NaN     iFixit     0.000000
# 57459          NaN     iFixit     0.000000
# 57489          NaN   Software     0.062508
#
# [1625 rows x 23 columns]

# %%
analysis_df
# Out:
#             id  id_order  product_id  product_quantity        sku  unit_price  \
# 0      1119116    299545           0                 1    OWC0100       47.49
# 1      1119119    299546           0                 1    IOT0014       18.99
# 2      1119120    295347           0                 1    APP0700       72.19
# 3      1119134    299556           0                 1  CRU0039-A       60.90
# 4      1119145    299561           0                 1    PEB0015      142.49
# ...        ...       ...         ...               ...        ...         ...
# 57578  1649474    525664           0                 1    TUC0207       16.52
# 57579  1649512    527070           0                 2    APP0698        9.99
# 57580  1649522    527074           0                 2    APP0698        9.99
# 57581  1649565    527096           0                 3    APP0698        9.99
# 57582  1649593    527112           0                 1    APP0698        9.99
#
#                      date                                               name  \
# 0     2017-01-01 01:46:16  OWC In-line Digital Temperature Sensor Kit HDD...
# 1     2017-01-01 01:50:34               iOttie Easy View 2 Car Black Support
# 2     2017-01-01 01:54:11  Apple 85W MagSafe 2 charger MacBook Pro screen...
# 3     2017-01-01 02:20:14                 (Open) Crucial 240GB SSD 7mm BX200
# 4     2017-01-01 02:38:50                 Pebble Smartwatch Time Steel Black
# ...                   ...                                                ...
# 57578 2018-03-14 11:45:05  Tucano Elements Second Skin Macbook Sleeve 12 ...
# 57579 2018-03-14 11:49:01  Apple Lightning Cable Connector to USB 1m Whit...
# 57580 2018-03-14 11:49:36  Apple Lightning Cable Connector to USB 1m Whit...
# 57581 2018-03-14 11:54:35  Apple Lightning Cable Connector to USB 1m Whit...
# 57582 2018-03-14 11:58:13  Apple Lightning Cable Connector to USB 1m Whit...
#
#                                                     desc   price  ... revenue  \
# 0      Kit temperature sensor for HDD iMac 21 inch an...   60.99  ...   47.49
# 1      IPhone car holder 7 plus / 7/6 Plus / 6 / 5s /...   22.95  ...   18.99
# 2      Apple MagSafe 2 Charger for MacBook Pro 15-inc...   89.00  ...   72.19
# 3      SSD hard drive and high-speed performance with...   76.99  ...   60.90
# 4      Bluetooth Smart Watch with steel case leather ...  299.99  ...  142.49
# ...                                                  ...     ...  ...     ...
# 57578  velvety inner protective case for MacBook 12 i...   24.99  ...   16.52
# 57579  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...   19.98
# 57580  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...   19.98
# 57581  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...   29.97
# 57582  Apple Lightning USB Cable 1 meter to charge an...   25.00  ...    9.99
#
#                product_category  year  month order_month  brand_name_x  \
# 0                       desktop  2017      1     2017-01           NaN
# 1                         other  2017      1     2017-01           NaN
# 2               laptop, charger  2017      1     2017-01           NaN
# 3                       storage  2017      1     2017-01           NaN
# 4       case, strap, smartwatch  2017      1     2017-01           NaN
# ...                         ...   ...    ...         ...           ...
# 57578  laptop, case, protection  2018      3     2018-03           NaN
# 57579                     cable  2018      3     2018-03           NaN
# 57580                     cable  2018      3     2018-03           NaN
# 57581                     cable  2018      3     2018-03           NaN
# 57582                     cable  2018      3     2018-03           NaN
#
#        brand_code brand_name_y brand_name discount_pct
# 0             OWC          NaN        OWC     0.221348
# 1             IOT          NaN     iOttie     0.172549
# 2             APP          NaN      Apple     0.188876
# 3             CRU          NaN    Crucial     0.208988
# 4             PEB          NaN     Pebble     0.525018
# ...           ...          ...        ...          ...
# 57578         TUC          NaN     Tucano     0.338936
# 57579         APP          NaN      Apple     0.600400
# 57580         APP          NaN      Apple     0.600400
# 57581         APP          NaN      Apple     0.600400
# 57582         APP          NaN      Apple     0.600400
#
# [57583 rows x 23 columns]
